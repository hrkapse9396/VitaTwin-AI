# %% [markdown]
# Module 1 ✅ Dataset Collection

# %%
import os

path = r"C:\Users\hrkap\OneDrive\Desktop\VitaTwin-AI project\datasets\raw\afdb"

print(os.path.exists(path))
print(os.listdir(path)[:20])
# Out:
# True
# ['00735.atr', '00735.hea', '00735.qrs', '03665.atr', '03665.hea', '03665.qrs', '04015.atr', '04015.dat', '04015.hea', '04015.hea-', '04015.qrs', '04043.atr', '04043.dat', '04043.hea', '04043.hea-', '04043.qrs', '04048.atr', '04048.dat', '04048.hea', '04048.hea-']

# %%
import wfdb

record = wfdb.rdrecord(
    r"C:\Users\hrkap\OneDrive\Desktop\VitaTwin-AI project\datasets\raw\afdb\04015"
)

print(record)

# %%
import wfdb
import matplotlib.pyplot as plt

record = wfdb.rdrecord(
    r"C:\Users\hrkap\OneDrive\Desktop\VitaTwin-AI project\datasets\raw\afdb\04015"
)

signal = record.p_signal[:,0]

plt.figure(figsize=(15,5))
plt.plot(signal[:5000])
plt.title("ECG Signal - Record 04015")
plt.xlabel("Samples")
plt.ylabel("Amplitude")
plt.grid(True)
plt.show()

# %%
import os

path = r"C:\Users\hrkap\OneDrive\Desktop\VitaTwin-AI project\datasets\raw\afdb"

for file in os.listdir(path):
    if file.endswith(".dat"):
        print(file)
# Out:
# 04015.dat
# 04043.dat
# 04048.dat
# 04126.dat
# 04746.dat
# 04908.dat
# 04936.dat
# 05091.dat
# 05121.dat
# 05261.dat
# 06426.dat
# 06453.dat
# 06995.dat
# 07162.dat
# 07859.dat
# 07879.dat
# 07910.dat
# 08215.dat
# 08219.dat
# 08378.dat
# 08405.dat
# 08434.dat
# 08455.dat

# %%
with open(
    r"C:\Users\hrkap\OneDrive\Desktop\VitaTwin-AI project\datasets\raw\afdb\00735.hea",
    "r"
) as f:
    print(f.read())
# Out:
# 00735 0 250 0
